# %%
"""  now today revison of ml for the """
# Out:
# '  now today revison of ml for the '

# %% [markdown]
#  step:
#  import modules/libraries
#   -  separate independent/dependent variable
#   -

# %%
# !pip install scikit-learn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score

import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('Salary_data.csv ')

# %%
df= pd.DataFrame(data)
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
df.shape
# Out:
# (30, 2)

# %%
plt.scatter(df['YearsExperience'],df['Salary'])
plt.title('Experience vs salary')
plt.xlabel('yaers of experince')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## step 1  Separate independent Data and dependent Data

# %%
df.ndim
# Out:
# 2

# %%
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
x=df[['YearsExperience']]
y=df[['Salary']]

# %%
x
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
y
# Out:
#     Salary
# 0    39343
# 1    46205
# 2    37731
# 3    43525
# 4    39891
# 5    56642
# 6    60150
# 7    54445
# 8    64445
# 9    57189
# 10   63218
# 11   55794
# 12   56957
# 13   57081
# 14   61111
# 15   67938
# 16   66029
# 17   83088
# 18   81363
# 19   93940
# 20   91738
# 21   98273
# 22  101302
# 23  113812
# 24  109431
# 25  105582
# 26  116969
# 27  112635
# 28  122391
# 29  121872

# %% [markdown]
# ## step 2 Split Data into Train and Test

# %%
x_train, x_test, y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=34)

# %%
x_train.shape
# Out:
# (24, 1)

# %%
y_test.shape
# Out:
# (6, 1)

# %%
x_train
# Out:
#     YearsExperience
# 15              4.9
# 7               3.2
# 28             10.3
# 13              4.1
# 20              6.8
# 25              9.0
# 23              8.2
# 16              5.1
# 18              5.9
# 0               1.1
# 24              8.7
# 6               3.0
# 14              4.5
# 27              9.6
# 11              4.0
# 5               2.9
# 3               2.0
# 4               2.2
# 21              7.1
# 22              7.9
# 9               3.7
# 10              3.9
# 26              9.5
# 1               1.3

# %%
y_test
# Out:
#     Salary
# 19   93940
# 12   56957
# 8    64445
# 29  121872
# 2    37731
# 17   83088

# %%
x_test
# Out:
#     YearsExperience
# 19              6.0
# 12              4.0
# 8               3.2
# 29             10.5
# 2               1.5
# 17              5.3

# %%
y_train
# Out:
#     Salary
# 15   67938
# 7    54445
# 28  122391
# 13   57081
# 20   91738
# 25  105582
# 23  113812
# 16   66029
# 18   81363
# 0    39343
# 24  109431
# 6    60150
# 14   61111
# 27  112635
# 11   55794
# 5    56642
# 3    43525
# 4    39891
# 21   98273
# 22  101302
# 9    57189
# 10   63218
# 26  116969
# 1    46205

# %%
x_train.shape,x_test.shape
# Out:
# ((24, 1), (6, 1))

# %%
y_train.shape,y_test.shape
# Out:
# ((24, 1), (6, 1))

# %% [markdown]
# ## step 3  Model Training(Linear regression)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# y=mx+c
model.coef_
# Out:
# array([[9503.63914882]])

# %%
model.intercept_
# Out:
# array([24876.57973823])

# %%
x_train
# Out:
#     YearsExperience
# 15              4.9
# 7               3.2
# 28             10.3
# 13              4.1
# 20              6.8
# 25              9.0
# 23              8.2
# 16              5.1
# 18              5.9
# 0               1.1
# 24              8.7
# 6               3.0
# 14              4.5
# 27              9.6
# 11              4.0
# 5               2.9
# 3               2.0
# 4               2.2
# 21              7.1
# 22              7.9
# 9               3.7
# 10              3.9
# 26              9.5
# 1               1.3

# %%
x_test
# Out:
#     YearsExperience
# 19              6.0
# 12              4.0
# 8               3.2
# 29             10.5
# 2               1.5
# 17              5.3

# %%
y_train.head(2)
# Out:
#     Salary
# 15   67938
# 7    54445

# %% [markdown]
# ## step 4 model prediction

# %%
y_test_pred=model.predict(x_test)

# %%
y_test_pred
# Out:
# array([[ 81898.41463113],
#        [ 62891.1363335 ],
#        [ 55288.22501444],
#        [124664.79080081],
#        [ 39132.03846145],
#        [ 75245.86722696]])

# %%
y_test
# Out:
#     Salary
# 19   93940
# 12   56957

# %%
y_test_pred[:2]
# Out:
# array([[81898.41463113],
#        [62891.1363335 ]])

# %% [markdown]
# ## step 5  model evaluation

# %%
mean_squared_error(y_test ,y_test_pred)
# Out:
# 55886986.002330534

# %%
r2_score(y_test ,y_test_pred)*100
# Out:
# 92.44141448042443

# %%
plt.scatter(x,y)
plt.plot(x,model.prdiction(x))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[126], line 2
#       1 plt.scatter(x,y)
# ----> 2 plt.plot(x,model.prdiction(x))
#
# AttributeError: 'LinearRegression' object has no attribute 'prdiction'
